# %% [markdown]
# /Users/audrey/Desktop/Health_Insurance_Dataset.xlsx'

# %% [markdown]
# #  Part I: Univariate and Bivariate Statistical Analysis and Visualization

# %%
pip install kaleido
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 MB 7.7 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset using read_excel() since it's an Excel file
df = pd.read_excel('/Users/audrey/Desktop/Health_Insurance_Dataset.xlsx') 

# Check the column names to confirm
print(df.columns)

# Clean the 'charges' column to remove non-numeric values
df['charges'] = pd.to_numeric(df['charges'], errors='coerce')  # Convert non-numeric values to NaN

# Drop rows where 'charges' is NaN (this removes non-numeric values)
df = df.dropna(subset=['charges'])
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges', 'Level',
#        'score'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. BMI Distribution
plt.figure(figsize=(10,6))
sns.histplot(df['bmi'], bins=20, kde=True)
plt.title('Distribution of BMI')
plt.xlabel('BMI')

# Save the plot as a JPEG image
plt.savefig("/Users/audrey/Desktop/BMIDist.jpeg", format='jpeg')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Charges Distribution
plt.figure(figsize=(10,6))
sns.histplot(df['charges'], bins=20, kde=True)
plt.title('Distribution of Insurance Charges')
plt.xlabel('Charges')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/ChargesDist.jpeg", format='jpeg')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Univariate Analysis for Categorical Variables
# 1. Sex Distribution
plt.figure(figsize=(10,6))
sns.countplot(x='sex', data=df)
plt.title('Distribution of Sex')
plt.xlabel('Sex')
plt.ylabel('Count')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/SexDist.jpeg", format='jpeg')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Smoker Distribution
plt.figure(figsize=(10,6))
sns.countplot(x='smoker', data=df)
plt.title('Distribution of Smokers')
plt.xlabel('Smoker')
plt.ylabel('Count')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/SmokerDist.jpeg", format='jpeg')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bivariate Analysis for Continuous Variables
# 1. BMI vs Charges
plt.figure(figsize=(10,6))
sns.scatterplot(x='bmi', y='charges', data=df)
plt.title('Relationship between BMI and Charges')
plt.xlabel('BMI')
plt.ylabel('Charges')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/BMI_vs_Charges.jpeg", format='jpeg')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bivariate Analysis for Continuous Variables
# 2. Age vs Charges
plt.figure(figsize=(10,6))
sns.scatterplot(x='age', y='charges', data=df)
plt.title('Relationship between Age and Charges')
plt.xlabel('Age')
plt.ylabel('Charges')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/Age_vs_Charges.jpeg", format='jpeg')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bivariate Analysis for Categorical Variables
# 1. Smoker vs Charges
plt.figure(figsize=(10,6))
sns.boxplot(x='smoker', y='charges', data=df)
plt.title('Insurance Charges by Smoking Status')
plt.xlabel('Smoker')
plt.ylabel('Charges')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/Smoker_vs_Charges.jpeg", format='jpeg')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Region vs Charges
plt.figure(figsize=(10,6))
sns.boxplot(x='region', y='charges', data=df)
plt.title('Insurance Charges by Region')
plt.xlabel('Region')
plt.ylabel('Charges')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/Region_vs_Charges.jpeg", format='jpeg')

plt.show()

# %% [markdown]
# # B. Bivariate Statistics (Two Continuous and Two Categorical Variables)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bivariate Analysis for Continuous Variables
# 1. Scatterplot for BMI vs Charges
plt.figure(figsize=(10,6))
sns.scatterplot(x='bmi', y='charges', data=df)
plt.title('BMI vs Charges')
plt.xlabel('BMI')
plt.ylabel('Charges')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/BMI_vs_Charges1.jpeg", format='jpeg')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bivariate Analysis for Categorical and Continuous Variables
# 1. Boxplot for Charges based on Sex
plt.figure(figsize=(10,6))
sns.boxplot(x='sex', y='charges', data=df)
plt.title('Charges Distribution by Sex')
plt.xlabel('Sex')
plt.ylabel('Charges')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/ChargesDistributionbySex.jpeg", format='jpeg')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Boxplot for Charges based on Smoker
plt.figure(figsize=(10,6))
sns.boxplot(x='smoker', y='charges', data=df)
plt.title('Charges Distribution by Smoking Status')
plt.xlabel('Smoker')
plt.ylabel('Charges')

# Save the plot as a JPEG image to your desktop
plt.savefig("/Users/audrey/Desktop/ChargesDistributionbySmokingStatus.jpeg", format='jpeg')

plt.show()

# %% [markdown]
# # Part II: Parametric Statistical Testing

# %%
from scipy import stats

# Parametric Statistical Test: Independent t-test
# Separate the charges by smoker status
smoker_charges = df[df['smoker'] == 'yes']['charges']
non_smoker_charges = df[df['smoker'] == 'no']['charges']

# Perform independent t-test
t_stat, p_value = stats.ttest_ind(smoker_charges, non_smoker_charges)

print(f'T-statistic: {t_stat}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: 46.66492117272371
# P-value: 8.271435842179101e-283

# %% [markdown]
# # Part III: Nonparametric Statistical Testing

# %%
# Nonparametric Test: Mann-Whitney U Test
# Separate BMI by sex
male_bmi = df[df['sex'] == 'male']['bmi']
female_bmi = df[df['sex'] == 'female']['bmi']

# Perform Mann-Whitney U test
u_stat, p_value = stats.mannwhitneyu(male_bmi, female_bmi)

print(f'U-statistic: {u_stat}')
print(f'P-value: {p_value}')
# Out:
# U-statistic: 235332.0
# P-value: 0.10140128040285444
